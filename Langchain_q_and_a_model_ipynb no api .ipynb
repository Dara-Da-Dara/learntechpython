# %%
pip install -r /content/sample_data/requirements.txt
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (from -r /content/sample_data/requirements.txt (line 1)) (1.2.0)
# Collecting langchain-groq (from -r /content/sample_data/requirements.txt (line 2))
#   Downloading langchain_groq-1.1.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from -r /content/sample_data/requirements.txt (line 3)) (1.2.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from langchain->-r /content/sample_data/requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langchain->-r /content/sample_data/requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain->-r /content/sample_data/requirements.txt (line 1)) (2.12.3)
# Collecting groq<1.0.0,>=0.30.0 (from langchain-groq->-r /content/sample_data/requirements.txt (line 2))
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq->-r /content/sample_data/requirements.txt (line 2)) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq->-r /content/sample_data/requirements.txt (line 2)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq->-r /content/sample_data/requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq->-r /content/sample_data/requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq->-r /content/sample_data/requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain->-r /content/sample_data/requirements.txt (line 1)) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain->-r /content/sample_data/requirements.txt (line 1)) (0.4.59)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain->-r /content/sample_data/requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain->-r /content/sample_data/requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain->-r /content/sample_data/requirements.txt (line 1)) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain->-r /content/sample_data/requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r /content/sample_data/requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r /content/sample_data/requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r /content/sample_data/requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r /content/sample_data/requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r /content/sample_data/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r /content/sample_data/requirements.txt (line 1)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r /content/sample_data/requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq->-r /content/sample_data/requirements.txt (line 2)) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq->-r /content/sample_data/requirements.txt (line 2)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq->-r /content/sample_data/requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq->-r /content/sample_data/requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain->-r /content/sample_data/requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain->-r /content/sample_data/requirements.txt (line 1)) (1.12.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain->-r /content/sample_data/requirements.txt (line 1)) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain->-r /content/sample_data/requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain->-r /content/sample_data/requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain->-r /content/sample_data/requirements.txt (line 1)) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain->-r /content/sample_data/requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain->-r /content/sample_data/requirements.txt (line 1)) (2.5.0)
# Downloading langchain_groq-1.1.1-py3-none-any.whl (19 kB)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: groq, langchain-groq
# Successfully installed groq-0.37.1 langchain-groq-1.1.1

# %%
import os
os.environ["GROQ_API_KEY"] = " api key "

# %%
import os
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Make sure API key is set
os.environ["GROQ_API_KEY"] = " api key "

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0.2
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful AI assistant."),
        ("human", "{question}")
    ]
)

chain = prompt | llm | StrOutputParser()

print("🤖 LLaMA Chatbot (Groq) | type 'exit' to quit")

while True:
    q = input("\nYou: ")
    if q.lower() == "exit":
        break
    print("Bot:", chain.invoke({"question": q}))
# Out:
# 🤖 LLaMA Chatbot (Groq) | type 'exit' to quit
#
# You: what is langchain ?
# Bot: LangChain is an open-source framework for building large language models (LLMs) and multimodal AI applications. It was founded by David Kan, a well-known figure in the AI community, and is backed by notable investors such as a16z and Founders Fund.
#
# LangChain's primary goal is to make it easier for developers to build and deploy AI applications that can interact with users in a more natural and intuitive way. The framework provides a set of tools and APIs that enable developers to create applications that can understand and respond to user input, generate text and images, and perform other tasks that require advanced AI capabilities.
#
# Some of the key features of LangChain include:
#
# 1. **LLM integration**: LangChain provides a simple and intuitive way to integrate LLMs into applications, making it easier to build and deploy AI-powered features.
# 2. **Multimodal support**: LangChain supports the integration of multiple modalities, such as text, images, and audio, enabling developers to build applications that can interact with users in different ways.
# 3. **API-first design**: LangChain's API-first design makes it easy to integrate with other services and applications, enabling developers to build complex AI-powered systems.
# 4. **Extensive documentation**: LangChain has extensive documentation and a large community of developers who contribute to the project, making it easier for new developers to get started.
#
# LangChain has a wide range of use cases, including:
#
# 1. **Chatbots**: LangChain can be used to build chatbots that can understand and respond to user input in a more natural and intuitive way.
# 2. **Virtual assistants**: LangChain can be used to build virtual assistants that can perform tasks such as scheduling appointments, sending emails, and making phone calls.
# 3. **Content generation**: LangChain can be used to generate high-quality content, such as articles, social media posts, and product descriptions.
# 4. **Image and video generation**: LangChain can be used to generate high-quality images and videos, enabling developers to build applications that can create visual content.
#
# Overall, LangChain is a powerful framework that enables developers to build complex AI-powered applications with ease. Its extensive documentation, large community, and API-first design make it an attractive choice for developers looking to build the next generation of AI-powered applications.
