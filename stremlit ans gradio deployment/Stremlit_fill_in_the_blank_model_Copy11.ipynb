# %%
! pip install streamlit -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 102.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 130.6 MB/s eta 0:00:00

# %% [markdown]
# | Step | Command                              | Purpose                                                                                      | Notes / Output                                                                                        |
# | ---- | ------------------------------------ | -------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------- |
# | 1    | `!pip install streamlit -q`          | Installs **Streamlit**, a Python library for building web apps                               | `-q` = quiet mode; Output shows download size and speed (`9.1 MB`, `6.9 MB`)                          |
# | 2    | `!npm install -g localtunnel`        | Installs **LocalTunnel** globally via npm, to expose local servers to the internet           | Useful for Colab since it doesn’t have a public URL; Output: 22 packages added, 3 looking for funding |
# | 3    | `!wget -q -O - ipv4.icanhazip.com`   | Fetches the **public IPv4 address** of the machine                                           | `-q` quiet, `-O -` prints output; Example output: `34.34.24.204`                                      |
# | 4    | `pip install streamlit transformers` | Installs **Streamlit** (again, may be redundant) and **Transformers** library for NLP models | Needed to run AI/ML models (BERT, GPT, etc.) in the Streamlit app                                     |

# %%
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧
# added 22 packages in 2s
# ⠧
# ⠧3 packages are looking for funding
# ⠧  run `npm fund` for details
# ⠧

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.34.24.204

# %%
pip install streamlit transformers

# %% [markdown]
# before the belo code of third line create a file app.py and write a code in it

# %%
! streamlit run /content/sample_data/app11.py & npx localtunnel --port 8501
# Out:
# ⠙
# ...
#
# ⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸your url is: https://giant-moles-sin.loca.lt
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.34.24.204:8501
#
# 2026-02-02 16:49:43.994119: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770050984.015130    3729 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770050984.021701    3729 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
